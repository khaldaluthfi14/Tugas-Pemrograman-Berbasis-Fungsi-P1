# %% [markdown]
# **Tugas PBF Pertemuan 1**
#
# **Nama: Khalda Luthfi A.**
#
# **NIM: 121450160**
#
# **Kelas: RB**

# %% [markdown]
# ![1.PNG](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **6.Membuat program simple password encrtption, dengan ketentuan:**
# 1. Input password bertipe string dengan batasan panjang password 100 karakter.
# 2. Setiap karakter dari string tersebut diubah menjadi ASCII value.
# 3. Kemudian setiap ASCII value tersebut dikembangkan menjadi 3 value dengan dilakukan operasi berikut:
#
#   A. Value pertama dibagi dengan integer 26 kemudian dibulatkan dan dijumlahkan dengan 80 kemudian diubah kembali menjadi karakter.
#
#   B. Value kedua dihitung sisa bagi dengan 26 kemudian dijumlahkan dengan 80 kemudian diubah kembali menjadi karakter.
#
#   C. Value ketiga adalah karakter '+' jika value pertama lebih besar dari value kedua, atau value ketiga adalah karakter '-' jika value pertama tidak lebih besar dari value kedua.
#
#   D. Deretkan value pertama, kedua dan ketiga untuk setiap karakter dalam password tersebut sehingga didapatkan password dalam bentuk baru.

# %%
def encrypt(password):
  if len(password) > 100 or len(password) == 0:
    print("Masukkan dan pilih angka dari 1 sampai 100")
  else:
    ascii_value = [str(ord(i)) for i in password]
    encrypt_value = ''.join(chr((int(j)//26)+80)+chr((int(j)%26)+80)+('+' if (int(j)//26)+80 > (int(j)%26)+80 else '-') for j in ascii_value)
    print("Enkripsi password anda adalah: ", encrypt_value)

def encrypted_value(password):
  split_ps = [(password[k:k+3]) for k in range(0, len(password), 3)]
  desc = ''.join(chr(((ord(list(z)[0])-80)*26)+(ord(list(z)[1])-80)) for z in split_ps)
  print("Password anda adalah: ", desc)

password = input("Masukkan Password: ")
encrypt (password)

new = input("Masukkan enkripsi password ")
encrypted_value(new)
# Out:
# Masukkan Password: 14045
# Enkripsi password anda adalah:  Qg-RP+Qf-RP+RQ+
# Masukkan enkripsi password Qg-RP+Qf-RP+RQ+
# Password anda adalah:  14045
